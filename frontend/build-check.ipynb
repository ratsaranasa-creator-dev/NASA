# %%
import json
from pathlib import Path

project_dir = Path('a:/site-web-de-dembéni/frontend')
package_json_path = project_dir / 'package.json'
package_lock_path = project_dir / 'package-lock.json'

print('Project:', project_dir)
print('package.json exists:', package_json_path.exists())
print('package-lock.json exists:', package_lock_path.exists())

# %% [markdown]
# # Create React App Build Repair for Vercel
#
# This notebook inspects and repairs the frontend React app to make it compatible with Vercel deployment. It focuses on dependency compatibility, cleaning the install, and verifying a successful production build.
